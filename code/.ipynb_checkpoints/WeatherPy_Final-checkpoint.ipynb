# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import logging
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
mx_temps= []
clouds = []
countries = []
dates = []
humidity = []
w_lats = []
w_lngs = []
wnd_spds = []
counter = 0
print("Beginning Data Retrieval")
print("------------------------")
for city in cities:
    counter +=1
    try:
        query_url = base_url + "appid=" + api_key + "&q=" + city + "&units=" + units
        weather_response = (requests.get(query_url).json())
   
        mx_temp = weather_response["main"]["temp_max"]
        cloud = weather_response["clouds"]["all"]
        country = weather_response["sys"]["country"]
        date = weather_response["dt"]
        humid = weather_response["main"]["humidity"]
        lat = weather_response["coord"]["lat"]
        long = weather_response["coord"]["lon"]
        speed =  weather_response["wind"]["speed"]
    except:
        print("City not found. Skipping...")
    
    print(f"Processing Record {counter} :| {city}")
    mx_temps.append(mx_temp)
    clouds.append(cloud)
    countries.append(country)
    dates.append(date)
    humidity.append(humid)  
    w_lats.append(lat)
    w_lngs.append(long)
    wnd_spds.append(speed)
    

weather_dict = {"City":cities, "Cloudiness":clouds, "Country":countries, "Date":dates, "Humidity":humidity, 
                "Lat":w_lats,"Lng":w_lngs, "Max Temp":mx_temps, "Wind Speed":wnd_spds}

weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 :| rikitea
# Processing Record 2 :| busselton
# City not found. Skipping...
# Processing Record 3 :| balderas
# Processing Record 4 :| pudozh
# Processing Record 5 :| hokitika
# Processing Record 6 :| tanout
# Processing Record 7 :| pisco
# Processing Record 8 :| codrington
# Processing Record 9 :| hilo
# Processing Record 10 :| tagusao
# Processing Record 11 :| cape town
# Processing Record 12 :| punta arenas
# Processing Record 13 :| lumsden
# Processing Record 14 :| kapaa
# City not found. Skipping...
# Processing Record 15 :| saleaula
# Processing Record 16 :| siderno
# City not found. Skipping...
# Processing Record 17 :| samusu
# Processing Record 18 :| bredasdorp
# Processing Record 19 :| qaanaaq
# Processing Record 20 :| hermanus
# Processing Record 21 :| haines junction
# Processing Record 22 :| cap malheureux
# Processing Record 23 :| pascagoula
# Processing Record 24 :| atasu
# Processing Record 25 :| saskylakh
# Processing Record 26 :| kremenki
# Processing Record 27 :| russell
# Processing Record 28 :| iqaluit
# Processing Record 29 :| ushuaia
# Processing Record 30 :| bluff
# Processing Record 31 :| puerto ayora
# Processing Record 32 :| dikson
# Processing Record 33 :| port elizabeth
# Processing Record 34 :| arraial do cabo
# Processing Record 35 :| balaipungut
# Processing Record 36 :| elk plain
# City not found. Skipping...
# Processing Record 37 :| sakakah
# Processing Record 38 :| camacha
# Processing Record 39 :| ukwa
# Processing Record 40 :| lasa
# Processing Record 41 :| kavali
# Processing Record 42 :| ambilobe
# Processing Record 43 :| albany
# City not found. Skipping...
# Processing Record 44 :| samalaeulu
# Processing Record 45 :| verdun
# Processing Record 46 :| constitucion
# Processing Record 47 :| konskie
# Processing Record 48 :| kruisfontein
# Processing Record 49 :| dabakala
# Processing Record 50 :| lebu
# Processing Record 51 :| sassandra
# Processing Record 52 :| ribeira grande
# City not found. Skipping...
# Processing Record 53 :| illoqqortoormiut
# City not found. Skipping...
# Processing Record 54 :| tubruq
# Processing Record 55 :| atuona
# Processing Record 56 :| souillac
# City not found. Skipping...
# Processing Record 57 :| taolanaro
# Processing Record 596 :| gopalpur
# Processing Record 597 :| marsh harbour
# City not found. Skipping...
# Processing Record 598 :| andenes
# Processing Record 599 :| honiara
# City not found. Skipping...
# Processing Record 600 :| ardistan
# Processing Record 601 :| rivera
# Processing Record 602 :| atar
# Processing Record 603 :| santa ines
# Processing Record 604 :| ikongo
# Processing Record 605 :| venancio aires
# Processing Record 606 :| vyazma
# Processing Record 607 :| gboko
# Processing Record 608 :| thinadhoo
# Processing Record 609 :| kloulklubed
# Processing Record 610 :| shiyan
# Processing Record 611 :| sitarganj
# Processing Record 612 :| hirara
# Processing Record 613 :| saquisili
# City not found. Skipping...
# Processing Record 614 :| sorvag
# Processing Record 615 :| lerwick
# Processing Record 616 :| havoysund
# Processing Record 617 :| maryborough
# Processing Record 618 :| north bend
# Processing Record 619 :| shenjiamen
# City not found. Skipping...
# Processing Record 620 :| bolungarvik
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    rikitea          88      PF  1550949578        98 -23.12 -134.97
# 1  busselton          36      AU  1550949579       100 -33.64  115.35
# 2   balderas          36      AU  1550949579       100 -33.64  115.35
# 3     pudozh          44      RU  1550949579        75  61.81   36.54
# 4   hokitika          92      NZ  1550949579       100 -42.72  170.96
#
#    Max Temp  Wind Speed
# 0     80.31       10.33
# 1     66.63       10.56
# 2     66.63       10.56
# 3     19.52        4.85
# 4     55.79       13.47

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
weather_df.to_csv("../output/weather_output.csv")

# %%
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    rikitea          88      PF  1550949578        98 -23.12 -134.97
# 1  busselton          36      AU  1550949579       100 -33.64  115.35
# 2   balderas          36      AU  1550949579       100 -33.64  115.35
# 3     pudozh          44      RU  1550949579        75  61.81   36.54
# 4   hokitika          92      NZ  1550949579       100 -42.72  170.96
#
#    Max Temp  Wind Speed
# 0     80.31       10.33
# 1     66.63       10.56
# 2     66.63       10.56
# 3     19.52        4.85
# 4     55.79       13.47

# %%
#Find outliers
outliers_index = weather_df.query("Humidity>100 or Humidity==0").index

# %%
#Drop outliers
weather_df.drop(index = outliers_index, inplace=True)

# %% [markdown]
# ### Plotting the Data

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Plot Data
plt.scatter(weather_df["Lat"],weather_df["Max Temp"],marker="o", facecolors="blue",edgecolors="black")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(b=True)
plt.savefig("../output/WeatherPy_Lat_vs_MaxTemp.png")

# %%
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"],marker="o", facecolors="blue",edgecolors="black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(b=True)
plt.savefig("../output/WeatherPy_Lat_vs_Humidity.png")

# %%
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"],marker="o", facecolors="blue",edgecolors="black")
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(b=True)
plt.savefig("../output/WeatherPy_Lat_vs_Cloudiness.png")

# %%
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"],marker="o", facecolors="blue",edgecolors="black")
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(b=True)
plt.savefig("../output/WeatherPy_Lat_vs_WindSpeed.png")

# %%
plt.show()

# %% [markdown]
# # Analysis
#
# ### Latitude and Temperature
# * The temperature generally gets higher as you approach the equator (0) latitude. However the max temperature at the lower latitudes are higher than those at the higher latitudes.
#
# ### Latitude and Humidity
# * Humidity appears random when compared to latitudes. There was no discernable pattern.
#
# ### Latitude and Cloudiness
# * Cloudiness appears random when compared across latitudes.
#
# ### Latitude and Wind Speed
# * Wind speeds appear to be clustered between 0 to 10 mph. There were significant outliers.
